# %% [markdown]
# <a href="https://colab.research.google.com/github/KuroNyth/biblioteca_pandas/blob/main/Matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
