# %% [markdown]
# <a href="https://colab.research.google.com/github/KuroNyth/biblioteca_pandas/blob/main/Markdown_Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
#Lendo o arquivo em csv
df = pd.read_csv("Salaries.csv", sep=",")
# Out:
# /tmp/ipython-input-1969257752.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Salaries.csv", sep=",")

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
#visualizar as (n) primeiras linhas
df.head(2)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN

# %% [markdown]
# Verifique os nulos e os tipos de dados

# %%
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# Descubra o volume de dados que o dataframe possui

# %%
df.count()
# Out:
# Id                  148654
# EmployeeName        148654
# JobTitle            148654
# BasePay             148049
# OvertimePay         148654
# OtherPay            148654
# Benefits            112495
# TotalPay            148654
# TotalPayBenefits    148654
# Year                148654
# Notes                    0
# Agency              148654
# Status               38119
# dtype: int64

# %%
len(df)
# Out:
# 148654

# %% [markdown]
# Qual é o basepay médio

# %%
df['BasePay']
# Out:
# 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object

# %%
df["BasePay"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3462676104.py in <cell line: 0>()
# ----> 1 df["BasePay"].mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
df[df['BasePay'] == 'Not Provided']
# Out:
#             Id  EmployeeName      JobTitle       BasePay   OvertimePay  \
# 148646  148647  Not provided  Not provided  Not Provided  Not Provided
# 148650  148651  Not provided  Not provided  Not Provided  Not Provided
# 148651  148652  Not provided  Not provided  Not Provided  Not Provided
# 148652  148653  Not provided  Not provided  Not Provided  Not Provided
#
#             OtherPay      Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148646  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148650  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148651  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148652  Not Provided  Not Provided       0.0               0.0  2014    NaN
#
#                Agency Status
# 148646  San Francisco    NaN
# 148650  San Francisco    NaN
# 148651  San Francisco    NaN
# 148652  San Francisco    NaN

# %%
df = df[~(df['BasePay'] == 'Not Provided')]

# %%
df['BasePay'] = df['BasePay'].astype(float)
# Out:
# /tmp/ipython-input-7556307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BasePay'] = df['BasePay'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148650 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  object
#  5   OtherPay          148650 non-null  object
#  6   Benefits          112491 non-null  object
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148650 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 15.9+ MB

# %% [markdown]
# Qual é o maior OvertimePay do dataset?

# %%
df["OvertimePay"].astype(float).max()
# Out:
# 245131.88

# %%
valor_maximo = df["OvertimePay"].astype(float).max()

# %%
df[df["OvertimePay"]==valor_maximo]
# Out:
#    Id  EmployeeName                         JobTitle    BasePay OvertimePay  \
# 1   2  GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
#
#     OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 1  137811.38      NaN  538909.28         538909.28  2011    NaN
#
#           Agency Status
# 1  San Francisco    NaN

# %%
df[df["EmployeeName"] == "JOSEPH DRISCOLL"]["JobTitle"]
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
df[df["EmployeeName"] == "JOSEPH DRISCOLL"]["TotalPay"]
# Out:
# 24    270324.91
# Name: TotalPay, dtype: float64

# %%
df[df["BasePay"] == df["BasePay"].max()] #pessoa que ganha mais
# Out:
#           Id    EmployeeName         JobTitle    BasePay OvertimePay  \
# 72925  72926  Gregory P Suhr  Chief of Police  319275.01         0.0
#
#        OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 72925  20007.06  86533.21  339282.07         425815.28  2013    NaN
#
#               Agency Status
# 72925  San Francisco    NaN

# %%
df[df["BasePay"] == df["BasePay"].min()] #pessoa mais mal paga
# Out:
#           Id    EmployeeName      JobTitle  BasePay OvertimePay OtherPay  \
# 72832  72833  Irwin Sidharta  Junior Clerk  -166.01      249.02      0.0
#
#       Benefits  TotalPay  TotalPayBenefits  Year  Notes         Agency Status
# 72832     6.56     83.01             89.57  2012    NaN  San Francisco    NaN

# %%
df[df["BasePay"] < 0]
# Out:
#           Id            EmployeeName      JobTitle  BasePay OvertimePay  \
# 72832  72833          Irwin Sidharta  Junior Clerk  -166.01      249.02
# 72865  72866            Robert Scott  Junior Clerk  -121.63       182.7
# 72872  72873         Chung Huey Kung  Junior Clerk  -109.22      163.83
# 72874  72875               Jordan Li  Junior Clerk  -106.60       159.9
# 72878  72879         Richard Jackson  Junior Clerk  -101.88      153.08
# 72884  72885  DiMarco McGhee-Stewart  Junior Clerk   -93.14      139.97
# 72888  72889      Leopoldo Marasigan  Junior Clerk   -87.38      131.06
# 72894  72895          Douglas Avalos  Junior Clerk   -75.67      113.76
# 72908  72909         Norma Rodriguez  Junior Clerk   -59.59       89.65
# 72920  72921        Charles Williams  Junior Clerk   -30.58       45.87
# 72922  72923             John Draper         Clerk    -9.50       14.25
#
#       OtherPay Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# ...

# %%
# Média salarial por ano
df["Year"].value_counts()
# Out:
# Year
# 2014    38119
# 2013    37606
# 2012    36766
# 2011    36159
# Name: count, dtype: int64

# %%
df.groupby("Year").agg({"BasePay": ["mean"]})
# Out:
#            BasePay
#               mean
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %%
df.groupby("Year")["BasePay"].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
# Quantos títulos de trabalho existem
df["JobTitle"].nunique()
# Out:
# 2158

# %%
df["JobTitle"].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ...,
#        'Forensic Toxicologist Supervis', 'Conversion', 'Cashier 3'],
#       dtype=object)

# %%
#Quais os 5 empregos mais comuns
df["JobTitle"].value_counts()
# Out:
# JobTitle
# Transit Operator                   7036
# Special Nurse                      4389
# Registered Nurse                   3736
# Public Svc Aide-Public Works       2518
# Police Officer 3                   2421
#                                    ...
# TREE TOPPER SUPERVISOR II             1
# TRAINING TECHNICIAN                   1
# COURT AD RESOLUTION COORDINATOR       1
# ROOFER SUPERVISOR I                   1
# POWER PLANT SUPERVISOR I              1
# Name: count, Length: 2158, dtype: int64

# %%
#Quantas pessoas tem a palavra chefe (Chief) no nome?
def chef(valor):
  if "chief" in valor.lower():
    return True
  else:
    return False

# %%
df[df["JobTitle"].apply(chef)]
# Out:
#             Id         EmployeeName  \
# 4            5      PATRICK GARDNER
# 5            6       DAVID SULLIVAN
# 6            7            ALSON LEE
# 8            9       MICHAEL MORRIS
# 9           10   JOANNE HAYES-WHITE
# ...        ...                  ...
# 138011  138012     Sharon C Jackson
# 139620  139621          Anita S Lee
# 139709  139710     George D Vaughan
# 140080  140081  Patrick W Gillespie
# 140156  140157  Christopher L Ochoa
#
#                                             JobTitle    BasePay OvertimePay  \
# 4       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.0
# 5                          ASSISTANT DEPUTY CHIEF II  118602.00      8601.0
# 6                 BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01     89062.9
# 8                 BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64    86362.68
# 9             CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00         0.0
# ...
